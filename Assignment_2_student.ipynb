# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
 kill.sample(5)
# Out:
#         id           name      date   manner_of_death       armed   age  \
# 401    507  Usaamah Rahim  02/06/15              shot       knife  26.0
# 91     532   John  Sawyer  07/02/15              shot  toy weapon  26.0
# 352    449  Bruce Zalonka  12/05/15  shot and Tasered         gun  46.0
# 2521  2806          TK TK  26/07/17              shot         gun   NaN
# 1168  1332   Mark Minnick  06/03/16              shot         gun  51.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 401       M    B   Roslindale    MA                    False        other
# 91        M    W     Calimesa    CA                    False       attack
# 352       M    O     Honolulu    HI                    False       attack
# 2521      M  NaN  San Antonio    TX                    False       attack
# 1168      M    W         Azle    TX                     True       attack
#
#              flee  body_camera
# 401   Not fleeing        False
# ...

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
kill.skew()
# Out:
# id                        -0.014277
# age                        0.714931
# signs_of_mental_illness    1.157208
# body_camera                2.545901
# dtype: float64

# %%
sns.kdeplot(kill.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# with seaborn
plt.figure(figsize=(8,6))
sns.boxplot(kill.gender, kill.age, hue=kill["manner_of_death"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
fig, (ax1,ax2) = plt.subplots(nrows=2, figsize=(12,12))
sns.boxplot(kill.gender,kill.age,hue = kill.manner_of_death, palette = 'viridis', saturation = 1, width = 0.3, whis = 2,
            ax = ax1)
sns.boxplot(kill.gender,kill.age,hue = kill.manner_of_death, ax = ax2)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
fig, ax = plt.subplots(figsize=(10,8))
sns.swarmplot(x="gender", y="age", hue="manner_of_death", data=kill, order=["F","M"], size=9)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = kill.city.value_counts()[:12]
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Miami            18
# Austin           18
# St. Louis        15
# Indianapolis     14
# Oklahoma City    14
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(city_freq.index,
                city_freq.values)
ax.set_xticklabels(city_freq.index,rotation=50)
ax.set_title("Most dangerous cities", color="blue", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.countplot(x="city", data=kill, order=city_freq.index)
ax.set_xticklabels(city_freq.index,rotation=50)
ax.set_title("Most dangerous cities", color="blue", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill.state.value_counts()[:20]
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=state_freq.index, y=state_freq.values,data=kill)
ax.set_xticklabels(state_freq.index,rotation=50)
ax.set_title("Most dangerous cities", color="blue", fontsize=20, loc="center",fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.countplot(x="state", data=kill, order=state_freq.index)
ax.set_xticklabels(state_freq.index,rotation=50)
ax.set_title("Most dangerous cities", color="blue", fontsize=20, loc="center",fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Most dangerous cities')

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot(kill.signs_of_mental_illness);

# %%
#barplot
plt.figure(figsize=(10,6), dpi=90)
sns.barplot(x=kill.signs_of_mental_illness.value_counts().index,
           y=kill.signs_of_mental_illness.value_counts().values,
           ci=None)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
plt.figure(dpi = 100)
sns.countplot(x=kill.threat_level);

# %%
sns.catplot(x='threat_level', data=kill, kind='count');

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
sns.countplot(kill.flee);
